# %% [markdown]
# # Location Selection with E-NAUTILUS: Part 2
# _Running of E-NAUTILUS for decision making, and presentation of results_

# %%
import numpy as np
import pandas as pd
import polars as pl
import pickle
import folium
import json
# These are to just suppress warnings in the outputs of the example
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load results from previous session

# %%
file_name = "data/pf_test.pkl"

output = open(file_name, 'rb')
prev_session = pickle.load(output)

raw_ref_pf = prev_session["pf"]
prob = prev_session["prob"]
sites = prev_session["sites"]
cities = prev_session["cities"]
cities_adj2sites = prev_session["cities_adj2sites"]
total_pop = prev_session["total_pop"]

# %% [markdown]
# ## Load reference front and problem

# %%
output_flat = np.array(raw_ref_pf).flatten()

def process_lists(dict2conv):
    return {key: np.array(dict2conv[key]).flatten().tolist() for key in dict2conv.keys()}

# TODO include constraints in here too
output_dict = [
    output.optimal_objectives | 
    process_lists(output.optimal_variables) 
    for output in output_flat]

results = pl.DataFrame(output_dict)

results = results.unique(subset=("f_1", "f_2", "f_3", "f_4", "f_5"))

results = results.with_columns([
    (-pl.col("f_1")).alias("f_1_min"),
    (pl.col("f_2")).alias("f_2_min"),
    (pl.col("f_3")).alias("f_3_min"),
    (-pl.col("f_4")).alias("f_4_min"),
    (-pl.col("f_5")).alias("f_5_min")
])

nadir_point = {
  "f_1": float(results["f_1"].min()),
  "f_2": float(results["f_2"].max()),
  "f_3": float(results["f_3"].max()),
  "f_4": float(results["f_4"].min()),
  "f_5": float(results["f_5"].min())
}

results = results.unique()

display(results)

print(f"Nadir point: {nadir_point}")
print(f"Nadir point (problem): {prob.get_nadir_point()}")
print(f"Idedal point (problem): {prob.get_ideal_point()}")
# Out:
# shape: (131, 13)
# ┌───────┬──────┬──────────┬──────────┬───┬─────────┬──────────┬───────────┬────────────┐
# │ f_1   ┆ f_2  ┆ f_3      ┆ f_4      ┆ … ┆ f_2_min ┆ f_3_min  ┆ f_4_min   ┆ f_5_min    │
# │ ---   ┆ ---  ┆ ---      ┆ ---      ┆   ┆ ---     ┆ ---      ┆ ---       ┆ ---        │
# │ f64   ┆ f64  ┆ f64      ┆ f64      ┆   ┆ f64     ┆ f64      ┆ f64       ┆ f64        │
# ╞═══════╪══════╪══════════╪══════════╪═══╪═════════╪══════════╪═══════════╪════════════╡
# │ 242.0 ┆ 0.0  ┆ 4000.115 ┆ 160582.0 ┆ … ┆ 0.0     ┆ 4000.115 ┆ -160582.0 ┆ -17.750517 │
# │ 172.0 ┆ 0.0  ┆ 2862.55  ┆ 156353.0 ┆ … ┆ 0.0     ┆ 2862.55  ┆ -156353.0 ┆ -16.592217 │
# │ 228.0 ┆ 9.0  ┆ 4055.5   ┆ 142197.0 ┆ … ┆ 9.0     ┆ 4055.5   ┆ -142197.0 ┆ -25.14205  │
# │ 160.0 ┆ 0.0  ┆ 2515.72  ┆ 94553.0  ┆ … ┆ 0.0     ┆ 2515.72  ┆ -94553.0  ┆ -14.802117 │
# │ 48.0  ┆ 0.0  ┆ 804.235  ┆ 138737.0 ┆ … ┆ 0.0     ┆ 804.235  ┆ -138737.0 ┆ -4.3342    │
# │ …     ┆ …    ┆ …        ┆ …        ┆ … ┆ …       ┆ …        ┆ …         ┆ …          │
# │ 280.0 ┆ 8.0  ┆ 5040.01  ┆ 161142.0 ┆ … ┆ 8.0     ┆ 5040.01  ┆ -161142.0 ┆ -26.97125  │
# │ 207.0 ┆ 11.0 ┆ 3886.135 ┆ 30347.0  ┆ … ┆ 11.0    ┆ 3886.135 ┆ -30347.0  ┆ -27.493333 │
# │ 51.0  ┆ 5.0  ┆ 1079.755 ┆ 83756.0  ┆ … ┆ 5.0     ┆ 1079.755 ┆ -83756.0  ┆ -10.390633 │
# │ 31.0  ┆ 1.0  ┆ 532.26   ┆ 47757.0  ┆ … ┆ 1.0     ┆ 532.26   ┆ -47757.0  ┆ -5.519867  │
# │ 151.0 ┆ 0.0  ┆ 2532.58  ┆ 137412.0 ┆ … ┆ 0.0     ┆ 2532.58  ┆ -137412.0 ┆ -11.474167 │
# └───────┴──────┴──────────┴──────────┴───┴─────────┴──────────┴───────────┴────────────┘
# Nadir point: {'f_1': 0.0, 'f_2': 17.0, 'f_3': 5862.45, 'f_4': 0.0, 'f_5': 0.0}
# Nadir point (problem): {'f_1': 0, 'f_2': 17, 'f_3': 5862.45, 'f_4': 0, 'f_5': 0}
# Idedal point (problem): {'f_1': 298, 'f_2': 0, 'f_3': 0, 'f_4': 161142, 'f_5': 32.842883330999996}

# %% [markdown]
# ## Filter out dominated solutions

# %%
from pymoo.util.nds.non_dominated_sorting import find_non_dominated

pf = results.select(["f_1", "f_2", "f_3", "f_4", "f_5"]).to_numpy()

pf_mini = pf.copy()

pf_mini[:,0] = -pf_mini[:,0]
pf_mini[:,3] = -pf_mini[:,3]
pf_mini[:,4] = -pf_mini[:,4]

nd_inds = find_non_dominated(pf_mini)

nd_df = results[nd_inds,:]
display(nd_df)

reachable_indices = list(range(len(nd_df)))  # everything reachable from nadir
# Out:
# shape: (96, 13)
# ┌───────┬─────┬──────────┬──────────┬───┬─────────┬──────────┬───────────┬────────────┐
# │ f_1   ┆ f_2 ┆ f_3      ┆ f_4      ┆ … ┆ f_2_min ┆ f_3_min  ┆ f_4_min   ┆ f_5_min    │
# │ ---   ┆ --- ┆ ---      ┆ ---      ┆   ┆ ---     ┆ ---      ┆ ---       ┆ ---        │
# │ f64   ┆ f64 ┆ f64      ┆ f64      ┆   ┆ f64     ┆ f64      ┆ f64       ┆ f64        │
# ╞═══════╪═════╪══════════╪══════════╪═══╪═════════╪══════════╪═══════════╪════════════╡
# │ 242.0 ┆ 0.0 ┆ 4000.115 ┆ 160582.0 ┆ … ┆ 0.0     ┆ 4000.115 ┆ -160582.0 ┆ -17.750517 │
# │ 172.0 ┆ 0.0 ┆ 2862.55  ┆ 156353.0 ┆ … ┆ 0.0     ┆ 2862.55  ┆ -156353.0 ┆ -16.592217 │
# │ 228.0 ┆ 9.0 ┆ 4055.5   ┆ 142197.0 ┆ … ┆ 9.0     ┆ 4055.5   ┆ -142197.0 ┆ -25.14205  │
# │ 160.0 ┆ 0.0 ┆ 2515.72  ┆ 94553.0  ┆ … ┆ 0.0     ┆ 2515.72  ┆ -94553.0  ┆ -14.802117 │
# │ 48.0  ┆ 0.0 ┆ 804.235  ┆ 138737.0 ┆ … ┆ 0.0     ┆ 804.235  ┆ -138737.0 ┆ -4.3342    │
# │ …     ┆ …   ┆ …        ┆ …        ┆ … ┆ …       ┆ …        ┆ …         ┆ …          │
# │ 157.0 ┆ 0.0 ┆ 2607.04  ┆ 161142.0 ┆ … ┆ 0.0     ┆ 2607.04  ┆ -161142.0 ┆ -12.872567 │
# │ 84.0  ┆ 0.0 ┆ 1282.49  ┆ 125800.0 ┆ … ┆ 0.0     ┆ 1282.49  ┆ -125800.0 ┆ -9.225867  │
# │ 280.0 ┆ 8.0 ┆ 5040.01  ┆ 161142.0 ┆ … ┆ 8.0     ┆ 5040.01  ┆ -161142.0 ┆ -26.97125  │
# │ 31.0  ┆ 1.0 ┆ 532.26   ┆ 47757.0  ┆ … ┆ 1.0     ┆ 532.26   ┆ -47757.0  ┆ -5.519867  │
# │ 151.0 ┆ 0.0 ┆ 2532.58  ┆ 137412.0 ┆ … ┆ 0.0     ┆ 2532.58  ┆ -137412.0 ┆ -11.474167 │
# └───────┴─────┴──────────┴──────────┴───┴─────────┴──────────┴───────────┴────────────┘

# %% [markdown]
# ## Analyze PF

# %%
from pymoo.visualization.pcp import PCP
plot = PCP(title=("Results"),
           n_ticks=10,
           legend=(True, {'loc': "upper left"}),
           labels=["Total Patients Visited", "Under attended events", "Cost of events", "Population Covered", "Cumulative SVI"]
           )

solution_to_examine = 2
plot.add(pf)
plot.add(pf[solution_to_examine,:], linewidth=5, color="red", label="Solution A").show()

# %% [markdown]
# ## Correlation matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_mat = nd_df.to_pandas().iloc[:,0:5].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr_mat, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Helper functions

# %%
# Function to determine marker size based on population
def get_marker_size(population):
    return max(5, population / 1000)  # Adjust the divisor to scale marker size

def create_color_dict(cities, ev_cities, cc): 
    marker_color = {}
    for city in cities.loc[:,"city"]: 
        if city in ev_cities: 
            marker_color[city] = "orange"
        elif city in cc: 
            marker_color[city] = "yellow"
        else: 
            marker_color[city] = "grey"

    return marker_color

def select_point(results, sol_id): 

    return {
        "f_1": int(results.loc[sol_id, "Total patients served"]),
        "f_2": int(results.loc[sol_id, "# of visited sites that are under-attended"]),
        "f_3": float(results.loc[sol_id, "Total costs ($)"]),
        "f_4": float(results.loc[sol_id, "% pop with clinic access"]),
        "f_5": float(results.loc[sol_id, "Cumulative SVI"]),
        }


def clean_results(raw_results, intermediate_point=True): 
    # Transform objectives
    if intermediate_point: 
        results = pd.DataFrame(raw_results.intermediate_points)
    else:
        results = pd.DataFrame(raw_results.optimal_objectives)

    results = results.rename(columns={
                    "f_1": "Total patients served", 
                    "f_2": "# of visited sites that are under-attended", 
                    "f_3": "Total costs ($)", 
                    "f_4": "% pop with clinic access", 
                    "f_5": "Cumulative SVI"})

    results[["Total patients served"]] =  results[["Total patients served"]].astype(int)
    results[["Total costs ($)"]] = (results[["Total costs ($)"]]).round(2)
    results[["Cumulative SVI"]] = (results[["Cumulative SVI"]]).round(2)
    results[["% pop with clinic access"]] = ((results[["% pop with clinic access"]]/total_pop)*100).round(2)

    results.index.name = "Solution ID"

    return results

# %% [markdown]
# ## Calculate HV

# %%
from pymoo.indicators.hv import HV

ref_point = np.array(list(nadir_point.values()))
ref_point[0] = -ref_point[0]
ref_point[3] = -ref_point[3]
ref_point[4] = -ref_point[4]

ind = HV(ref_point=ref_point)

int(ind(pf))
# Out:
# 0

# %% [markdown]
# ## Run eNAUTILUS
# ### Round 1
# We're going to generate some solutions. They will be poor at first, but you and the computer will slowly find the best solution that fulfills your goals and preferences.

# %%
# Initialize a first solution 
from desdeo.mcdm.enautilus import enautilus_step
from desdeo.mcdm.enautilus import enautilus_get_representative_solutions

current_iter = 0
selected_point = nadir_point
total_iterations = 3
display(f"Starting with point {selected_point}")

prob.get_ideal_point()

raw_results = enautilus_step(
    problem=prob,
    non_dominated_points=nd_df,
    current_iteration=current_iter,
    iterations_left=total_iterations - current_iter,
    selected_point=selected_point,
    reachable_point_indices=reachable_indices,
    #total_number_of_iterations=total_iterations,
    number_of_intermediate_points=4,
)

print(f"number of iterations left: {total_iterations - current_iter}")

results = clean_results(raw_results)
display("Which solution to do you prefer?")
display(results)
# Out:
# "Starting with point {'f_1': 0.0, 'f_2': 17.0, 'f_3': 5862.45, 'f_4': 0.0, 'f_5': 0.0}"
# number of iterations left: 3
# 'Which solution to do you prefer?'
#              Total patients served  \
# Solution ID
# 0                                2
# 1                               45
# 2                               15
# 3                               17
#
#              # of visited sites that are under-attended  Total costs ($)  \
# Solution ID
# 0                                             11.333333          3933.63
# 1                                             13.666667          4744.27
# 2                                             13.666667          4263.14
# 3                                             13.000000          4268.22
#
#              % pop with clinic access  Cumulative SVI
# Solution ID
# 0                                1.28            0.13
# 1                               31.71            6.27
# 2                                9.88            3.68
# 3                               18.60            3.46

# %% [markdown]
# ### Round 2

# %%
chosen_solution = 2

# %%
# Refine solution based on feedback
current_iter += 1
selected_point = select_point(results, chosen_solution)

print(selected_point)

raw_results = enautilus_step(
    problem=prob,
    non_dominated_points=nd_df,
    current_iteration=current_iter,
    iterations_left=total_iterations - current_iter,
    selected_point=selected_point,
    reachable_point_indices=reachable_indices,
    #total_number_of_iterations=total_iterations,
    number_of_intermediate_points=4,
)

print(f"number of iterations left: {total_iterations - current_iter}")
display(raw_results)
results = clean_results(raw_results)
display("Which solution to do you find most preferable?")
display(results)
display("Results:")
# Out:
# {'f_1': 15, 'f_2': 13, 'f_3': 4263.14, 'f_4': 9.88, 'f_5': 3.68}
# number of iterations left: 2
# ENautilusResult(current_iteration=2, iterations_left=1, intermediate_points=[{'f_1': 10.5, 'f_2': 6.5, 'f_3': 2169.57, 'f_4': 3090.44, 'f_5': 2.035}, {'f_1': 76.0, 'f_2': 10.0, 'f_3': 3385.5275, 'f_4': 76650.44, 'f_5': 11.240766665999999}, {'f_1': 31.0, 'f_2': 10.0, 'f_3': 2663.83, 'f_4': 23883.44, 'f_5': 7.359866666}, {'f_1': 33.0, 'f_2': 9.0, 'f_3': 2671.4475, 'f_4': 44968.44, 'f_5': 7.0353166665}], reachable_best_bounds=[{'f_1': 133.0, 'f_2': 0.0, 'f_3': 532.26, 'f_4': 158556.0, 'f_5': 14.852566666}, {'f_1': 208.0, 'f_2': 0.0, 'f_3': 2166.38, 'f_4': 161142.0, 'f_5': 19.430799998}, {'f_1': 165.0, 'f_2': 0.0, 'f_3': 1053.315, 'f_4': 161142.0, 'f_5': 19.430799998}, {'f_1': 165.0, 'f_2': 0.0, 'f_3': 1053.315, 'f_4': 161142.0, 'f_5': 19.430799998}], reachable_worst_bounds=[{'f_1': 10.5, 'f_2': 6.5, 'f_3': 2169.57, 'f_4': 3090.44, 'f_5': 2.035}, {'f_1': 76.0, 'f_2': 10.0, 'f_3': 3385.5275, 'f_4': 76650.44, 'f_5': 11.240766665999999}, {'f_1': 31.0, 'f_2': 10.0, 'f_3': 2663.83, 'f_4': 23883.44, 'f_5': 7.359866666}, {'f_1': 33.0, 'f_2': 9.0, 'f_3': 2671.4475, 'f_4': 44968.44, 'f_5': 7.0353166665}], closeness_measures=[56.9228219841396, 50.01735322059441, 50.20414234212266, 50.06049192855896], reachable_point_indices=[[4, 19, 27, 29, 32, 44, 47, 49, 57, 59, 60, 63, 74, 79, 81, 88, 90, 92, 94], [1, 3, 7, 9, 10, 11, 12, 14, 18, 20, 21, 22, 23, 24, 26, 28, 33, 34, 35, 36, 40, 41, 43, 45, 50, 52, 53, 55, 56, 58, 62, 63, 65, 66, 67, 70, 75, 77, 78, 82, 83, 85, 87, 89, 91, 95], [3, 10, 19, 20, 23, 27, 29, 31, 33, 34, 35, 36, 38, 43, 44, 47, 49, 50, 52, 54, 57, 59, 60, 61, 63, 65, 70, 74, 75, 77, 78, 81, 88, 90, 91, 92, 95], [3, 10, 19, 20, 23, 27, 29, 31, 33, 34, 35, 36, 38, 43, 44, 47, 49, 50, 52, 54, 57, 59, 60, 61, 63, 65, 70, 74, 75, 77, 78, 81, 88, 90, 91, 92, 95]])
# 'Which solution to do you find most preferable?'
#              Total patients served  \
# Solution ID
# 0                               10
# 1                               76
# 2                               31
# 3                               33
#
#              # of visited sites that are under-attended  Total costs ($)  \
# Solution ID
# 0                                                   6.5          2169.57
# 1                                                  10.0          3385.53
# 2                                                  10.0          2663.83
# 3                                                   9.0          2671.45
#
#              % pop with clinic access  Cumulative SVI
# Solution ID
# 0                                1.92            2.04
# 1                               47.57           11.24
# 2                               14.82            7.36
# 3                               27.91            7.04
# 'Results:'

# %% [markdown]
# ### Round 3

# %%
chosen_solution = 2

# %%
# Refine solution based on feedback
current_iter += 1
selected_point = select_point(results, chosen_solution)

print(selected_point)

raw_results = enautilus_step(
    problem=prob,
    non_dominated_points=nd_df,
    current_iteration=current_iter,
    iterations_left=total_iterations - current_iter,
    selected_point=selected_point,
    reachable_point_indices=reachable_indices,
    #total_number_of_iterations=total_iterations,
    number_of_intermediate_points=4,
)

print(f"number of iterations left: {total_iterations - current_iter}")

results = clean_results(raw_results)
display("Which solution to do you find most preferable?")
display(results)
# Out:
# {'f_1': 31, 'f_2': 10, 'f_3': 2663.83, 'f_4': 14.82, 'f_5': 7.36}
# number of iterations left: 1
# 'Which solution to do you find most preferable?'
#              Total patients served  \
# Solution ID
# 0                                6
# 1                              137
# 2                               47
# 3                               51
#
#              # of visited sites that are under-attended  Total costs ($)  \
# Solution ID
# 0                                                   0.0            76.00
# 1                                                   7.0          2507.92
# 2                                                   7.0          1064.52
# 3                                                   5.0          1079.76
#
#              % pop with clinic access  Cumulative SVI
# Solution ID
# 0                                3.83            0.39
# 1                               95.13           18.80
# 2                               29.64           11.04
# 3                               55.81           10.39

# %% [markdown]
# ## Display final result

# %%
final_chosen_solution = 1

# %%
# Get final solution 
solutions = enautilus_get_representative_solutions(prob, raw_results, nd_df) 
solution = solutions[final_chosen_solution]
results = clean_results(solution, intermediate_point=False)

display(results)
# Out:
#              Total patients served  \
# Solution ID
# 0                              137
#
#              # of visited sites that are under-attended  Total costs ($)  \
# Solution ID
# 0                                                   7.0          2507.92
#
#              % pop with clinic access  Cumulative SVI
# Solution ID
# 0                               95.13            18.8

# %% [markdown]
# ### Result postprocessing

# %%
# Post process result...
raw_sites = solution.optimal_variables['sv'][0].to_list()
raw_sites = [[bool(e) for e in raw_sites]]

raw_coverage = solution.optimal_variables['cover'][0].to_list()
raw_coverage = [[bool(c) for c in raw_coverage]]

sites_visited = []
for evb in raw_sites: 
    sites_visited.append("\n".join(sites.loc[evb, "site_id"].values))

cities_covered = [] 
for cc in raw_coverage: 
    cities_covered.append("\n".join(cities.loc[cc,"city"].values))

results["Sites Visited"] = sites_visited
results["Cities covered"] = cities_covered

results
# Out:
#              Total patients served  \
# Solution ID
# 0                              137
#
#              # of visited sites that are under-attended  Total costs ($)  \
# Solution ID
# 0                                                   7.0          2507.92
#
#              % pop with clinic access  Cumulative SVI  \
# Solution ID
# 0                               95.13            18.8
#
#                                                  Sites Visited  \
# Solution ID
# 0            lima-lima-odb\nwapakoneta-wapak-ucc\nlima-chri...
#
#                                                 Cities covered
# Solution ID
# 0            Ada\nAlger\nBluffton\nCairo\nCarey\nColumbus G...

# %% [markdown]
# ### Map preprocessing

# %%
# Process for the map
sites_in_cities = sites.loc[raw_sites[0],:].groupby("city").agg({"site_pretty": lambda e : '<br>'.join(e)})
sites_in_cities = sites_in_cities.to_dict()['site_pretty']
sites_in_cities

# cc cities covered
cc = set(cities_covered[0].split('\n'))

site_cities = list(sites.loc[raw_sites[0], "city"])
marker_colors = create_color_dict(cities, site_cities, cc)


## Site coverage dictionary 
site2city_mat = cities_adj2sites[raw_sites[0]].astype(bool)

site2city_dict = {}
for (c,city) in enumerate(site_cities): 
    site2city_dict[city] = set(cities.loc[site2city_mat[c,],"city"]) - {city}

adjacent_sites = {}
# Record what sites are near other cities
for site_city in site2city_dict.keys(): 
    adj_cities = site2city_dict[site_city]
    from_name = cities.loc[cities.loc[:,"city"] == site_city,["city"]].values.tolist()[0][0]

    for adj_city in adj_cities: 
        to_name = cities.loc[cities.loc[:,"city"] == adj_city ,["city"]].values.tolist()[0][0]

        if to_name not in adjacent_sites.keys(): 
            adjacent_sites[to_name] = {from_name}
        else: 
            adjacent_sites[to_name] = adjacent_sites[to_name].union({from_name})

# %% [markdown]
# ## Render map

# %%
# Render map

# Create a base map
m = folium.Map(location=[cities['lat'].mean(), 
                         cities['long'].mean()], 
                         zoom_start=7) 

# Draw lines between 
for site_city in site2city_dict.keys(): 
    adj_cities = site2city_dict[site_city]
    from_loc = cities.loc[cities.loc[:,"city"] == site_city,["lat", "long"]].values.tolist()

    for adj_city in adj_cities: 
        to_loc = cities.loc[cities.loc[:,"city"] == adj_city ,["lat", "long"]].values.tolist()
        folium.PolyLine(
            locations=[to_loc[0], from_loc[0]],
            color="black"
        ).add_to(m)

# Set bounds
sw = cities.loc[:,['lat', 'long']].min().values.tolist()
ne = cities.loc[:,['lat', 'long']].max().values.tolist()
m.fit_bounds([sw,ne])

# Create tool tips 
tooltips = {}
for _, row in cities.iterrows():
    city = row['city']
    tooltips[city]=f"<b>{city}</b><br><b>Population:</b> {row['pop']}"

    if city in sites_in_cities.keys():
        tooltips[city]+= "<br><b>Sites with events:</b><br>"
        tooltips[city]+= sites_in_cities[city]
    else:
        tooltips[city]+= "<br><b>No Healthwise Clinics</b>"

    if city in adjacent_sites.keys(): 
        tooltips[city]+= "<br><b>Covered by events in: </b>"
        tooltips[city]+= "<br>".join(adjacent_sites[city])


# Add cities to the map
for _, row in cities.iterrows():
    city = row['city']
    folium.CircleMarker(
        location=(row['lat'], row['long']),
        radius=get_marker_size(row['pop']),
        color="black",
        fill=True,
        fill_color=marker_colors[city],
        fill_opacity=0.6,
        tooltip=tooltips[city]
    ).add_to(m)

display(results)
display(m)
# Out:
#              Total patients served  \
# Solution ID
# 0                              137
#
#              # of visited sites that are under-attended  Total costs ($)  \
# Solution ID
# 0                                                   7.0          2507.92
#
#              % pop with clinic access  Cumulative SVI  \
# Solution ID
# 0                               95.13            18.8
#
#                                                  Sites Visited  \
# Solution ID
# 0            lima-lima-odb\nwapakoneta-wapak-ucc\nlima-chri...
#
#                                                 Cities covered
# Solution ID
# 0            Ada\nAlger\nBluffton\nCairo\nCarey\nColumbus G...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d44e16ccce68a7e1a487c4b3553df297 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d44e16ccce68a7e1a487c4b3553df297&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d44e16ccce68a7e1a487c4b3553df297 = L.map(
#                 &quot;map_d44e16ccce68a7e1a487c4b3553df297&quot;,
#                 {
#                     center: [40.76572536111111, -83.87487647222221],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3850b0f9d69f46ad9dcb0fb093aa6a93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3850b0f9d69f46ad9dcb0fb093aa6a93.addTo(map_d44e16ccce68a7e1a487c4b3553df297);
#
#
#             var poly_line_8c9e3b321b07ba06beed8a15d6cbc932 = L.polyline(
#                 [[40.786667, -84.198889], [40.746389, -84.123333]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d44e16ccce68a7e1a487c4b3553df297);
#
#
#             var poly_line_5e800a95457116e154d6a4beb87f156b = L.polyline(
#                 [[40.830833, -84.084444], [40.746389, -84.123333]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d44e16ccce68a7e1a487c4b3553df297);
#
#
#             var poly_line_17b6b98d25181abb99b99963fa0783d0 = L.polyline(
#                 [[40.664722, -84.130833], [40.746389, -84.123333]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d44e16ccce68a7e1a487c4b3553df297);
#
#
#             var poly_line_138af336774267d1e2fb21aafc1b11f4 = L.polyline(
#                 [[40.768056, -83.825278], [40.709722, -83.844167]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d44e16ccce68a7e1a487c4b3553df297);
#
#
#             var poly_line_c1fcb94e295073a8e0041eff646689f8 = L.polyline(
#                 [[40.709722, -83.844167], [40.768056, -83.825278]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d44e16ccce68a7e1a487c4b3553df297);
#
#
#             var poly_line_f2908eaff524dfd5ac48351537b18d74 = L.polyline(
#                 [[41.008333, -84.0375], [40.920556, -84.059722]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: n

# %%
def build_echarts_map_option(
    cities,
    site2city_dict,
    sites_in_cities,
    adjacent_sites,
    marker_colors,
    get_marker_size,
):
    # -------------------------
    # Prepare lookup for coords
    # -------------------------
    city_coords = {
        row["city"]: [row["long"], row["lat"]]
        for _, row in cities.iterrows()
    }

    # -------------------------
    # Build line data
    # -------------------------
    lines_data = []
    for site_city, adj_cities in site2city_dict.items():
        if site_city not in city_coords:
            continue

        for adj_city in adj_cities:
            if adj_city not in city_coords:
                continue

            lines_data.append({
                "coords": [
                    city_coords[site_city],
                    city_coords[adj_city]
                ]
            })

    # -------------------------
    # Build scatter data
    # -------------------------
    scatter_data = []
    for _, row in cities.iterrows():
        city = row["city"]

        tooltip_html = (
            f"<b>{city}</b><br>"
            f"<b>Population:</b> {row['pop']}"
        )

        if city in sites_in_cities:
            tooltip_html += "<br><b>Sites with events:</b><br>"
            tooltip_html += sites_in_cities[city]
        else:
            tooltip_html += "<br><b>No Healthwise Clinics</b>"

        if city in adjacent_sites:
            tooltip_html += "<br><b>Covered by events in:</b><br>"
            tooltip_html += "<br>".join(adjacent_sites[city])

        scatter_data.append({
            "name": city,
            "value": [
                row["long"],
                row["lat"],
                row["pop"],
            ],
            "symbolSize": get_marker_size(row["pop"]),
            "itemStyle": {
                "color": marker_colors.get(city, "#5470C6"),
                "opacity": 0.6,
                "borderColor": "black",
                "borderWidth": 1,
            },
            "tooltip": {
                "formatter": tooltip_html
            }
        })

    # -------------------------
    # FINAL OPTION (NO GEO)
    # -------------------------
    option = {
        "tooltip": {
            "trigger": "item",
            "enterable": True,
        },

        # IMPORTANT: no "geo" block at all

        "series": [
            {
                "type": "lines",
                # REMOVE coordinateSystem:'geo'
                "data": lines_data,
                "lineStyle": {
                    "color": "black",
                    "width": 1,
                    "opacity": 0.7
                },
                "silent": True
            },
            {
                "type": "scatter",
                # REMOVE coordinateSystem:'geo'
                "data": scatter_data,
                "zlevel": 2
            }
        ]
    }

    return option

# %%
# Build the option dict
option = build_echarts_map_option(
    cities=cities,
    site2city_dict=site2city_dict,
    sites_in_cities=sites_in_cities,
    adjacent_sites=adjacent_sites,
    marker_colors=marker_colors,
    get_marker_size=get_marker_size,
)

# Write to JSON file
with open("echarts_map_option.json", "w", encoding="utf-8") as f:
    json.dump(option, f, indent=2)

# %%
def build_leaflet_map_json(
    cities,
    site2city_dict,
    sites_in_cities,
    adjacent_sites,
    marker_colors,
    get_marker_size,
):
    """
    Build a JSON structure optimized for Leaflet visualization.
    
    Output format:
    {
        "cities": [
            {
                "city": "Ada",
                "lat": 40.768056,
                "lon": -83.825278,
                "size": 5.3,
                "color": "orange",
                "tooltip": "<b>Ada</b><br>Population: 5334<br>..."
            },
            ...
        ],
        "lines": [
            { "from": "Ada", "to": "Alger" },
            ...
        ]
    }
    """

    # -------------------------
    # Build city list
    # -------------------------
    city_entries = []

    for _, row in cities.iterrows():
        city = row["city"]

        # Build tooltip HTML
        tooltip_html = (
            f"<b>{city}</b><br>"
            f"<b>Population:</b> {row['pop']}"
        )

        if city in sites_in_cities:
            tooltip_html += "<br><b>Sites with events:</b><br>"
            tooltip_html += sites_in_cities[city]
        else:
            tooltip_html += "<br><b>No Healthwise Clinics</b>"

        if city in adjacent_sites:
            tooltip_html += "<br><b>Covered by events in:</b><br>"
            tooltip_html += "<br>".join(adjacent_sites[city])

        city_entries.append({
            "city": city,
            "lat": row["lat"],
            "lon": row["long"],
            "size": get_marker_size(row["pop"]),
            "color": marker_colors.get(city, "#5470C6"),
            "tooltip": tooltip_html
        })

    # -------------------------
    # Build line list
    # -------------------------
    line_entries = []

    # site2city_dict maps from city -> list of connected cities
    for city_from, adj_list in site2city_dict.items():
        for city_to in adj_list:
            # Only include if both cities exist
            line_entries.append({
                "from": city_from,
                "to": city_to
            })

    # -------------------------
    # Final structure
    # -------------------------
    return {
        "cities": city_entries,
        "lines": line_entries
    }

leaflet_map = build_leaflet_map_json(
    cities=cities,
    site2city_dict=site2city_dict,
    sites_in_cities=sites_in_cities,
    adjacent_sites=adjacent_sites,
    marker_colors=marker_colors,
    get_marker_size=get_marker_size,
)

# Write to JSON file
with open("leaflet_data.json", "w", encoding="utf-8") as f:
    json.dump(leaflet_map, f, indent=2)
