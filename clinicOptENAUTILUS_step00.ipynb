# %% [markdown]
# ## Event/site preprocessing
# The primary goal of this preprocessing script is to project the expected foot traffic at each proprosed event

# %%
import pandas as pd
import numpy as np

propSites = pd.read_csv("data/proposedSites.csv")
sites = pd.read_csv("data/sites.csv")
events = pd.read_csv("data/events.csv")

# %% [markdown]
# ### Determining expected attenace
# There are three types of proposed site visits:
# 1. Sites that have already been visited
# 2. Sites that have not been visited, but are a type (e.g., Library, thirft shop, etc) that has been visited already
# 3. Sites that have not been visited, and are of a type that has never been visited before.
#
# To handle each of these cases:
#
# *Case 1*: Calculate statistics from historical data of that *exact* given site
#
# *Case 2*: Calculate statistics from historical data for that *type* of site
#
# *Case 3*: Calculate statistics from all sites ever visited

# %%
propSites["minAtt"] = np.ones((propSites.shape[0], 1))*-99
propSites["medAtt"] = np.ones((propSites.shape[0], 1))*-99
propSites["maxAtt"] = np.ones((propSites.shape[0], 1))*-99


for r, row in propSites.iterrows():
    name = row["siteName"]
    city = row["city"]

    # Determine the site ID (if it exists)
    site_mask = np.logical_and(sites.loc[:, "siteName"] == name, sites.loc[:, "city"] == city)

    siteId = sites.loc[site_mask, "siteId"].values
    siteType = row["siteType"].lower()

    if len(siteId) > 1: 
        ValueError("Error: duplicate events found in the site table.")        

    # Check if this site has been visisted yet 
    if len(siteId) == 0: 
        # Place holder if site has not been visited
        siteId = -99 
    else: 
        siteId = siteId[0]

    # Determine the events at the same location 
    same_site_mask = events.loc[:,"siteId"] == siteId
    past_events_same_site = events.loc[same_site_mask, :]

    # Determine the events of the same type 
    event_sites = events.merge(sites, on="siteId").loc[:,["eventId", "siteType", "footTraffic"]].drop_duplicates()
    events_same_type_mask = event_sites.loc[:,"siteType"] == siteType
    events_same_type = event_sites.loc[events_same_type_mask, :]

    #events_same_type_mask =  events.loc[:, "siteId"] 

    # CASE 1: Site has been visited before 
    if past_events_same_site.shape[0] > 0:
        propSites.loc[r, "minAtt"] = past_events_same_site.loc[:,"footTraffic"].min()
        propSites.loc[r, "medAtt"] = np.round(past_events_same_site.loc[:,"footTraffic"].median())
        propSites.loc[r, "maxAtt"] = past_events_same_site.loc[:,"footTraffic"].max()

    # CASE 2: Site not visited, but sites of the same type 
    elif siteId == -99 and events_same_type.shape[0] > 0:
        propSites.loc[r, "minAtt"] = events_same_type.loc[:,"footTraffic"].min()
        propSites.loc[r, "medAtt"] = np.round(events_same_type.loc[:,"footTraffic"].median())
        propSites.loc[r, "maxAtt"] = events_same_type.loc[:,"footTraffic"].max()

    # CASE 3: Site not visited, new site type
    else: 
        propSites.loc[r, "minAtt"] = events.loc[:,"footTraffic"].min()
        propSites.loc[r, "medAtt"] = np.round(events.loc[:,"footTraffic"].median())
        propSites.loc[r, "maxAtt"] = events.loc[:,"footTraffic"].max()

propSites
# Out:
#                  siteName                  siteType            city  minAtt  \
# 0            Alger Dinner           charitable meal           Alger     1.0
# 1                 DJ Kirk           charitable meal         Dunkirk     3.0
# 2                DJ Kirk            charitable meal         Dunkirk     2.0
# 3          Dunkirk Dinner           charitable meal         Dunkirk     3.0
# 4                Lima ODB           charitable meal            Lima     2.0
# 5         Saint Marks UMC                    church            Lima     2.0
# 6               Wapak UCC                    church      Wapakoneta     6.0
# 7           Grace Clinics                    clinic          Marion     0.0
# 8        Christian Corner                 food bank            Lima     0.0
# 9       Alger Food Pantry               food pantry           Alger     2.0
# 10                  Agape  food pantry;thrift store     Saint Marys     0.0
# 11                  Apape  food pantry;thrift store     Saint Marys     2.0
# 12            HardinCrest  food pantry;thrift store          Kenton     2.0
# 13            Kenton YMCA                       gym          Kenton     3.0
# 14                   YMCA                       gym          Kenton     0.0
# 15       Bluffton Library                   library        Bluffton     4.0
# 16           Lima Library                   library            Lima     3.0
# 17         Public Library                   library             Ada     3.0
# 18         Public Library                   library           Alger     3.0
# 19         Public Library                   library           Cairo     3.0
# 20         Public Library                   library       Caledonia     3.0
# 21         Public Library                   library           Carey     3.0
# 22         Public Library                   library  Columbus Grove     3.0
# 23         Public Library                   library     Continental     3.0
# 24         Public Library                   library         Delphos     3.0
# 25         Public Library                   library           Elida     3.0
# 26         Public Library                   library          Forest     3.0
# 27         Public Library                   library   Fort Jennings     3.0
# 28         Public Library                   library          Kalida     3.0
# 29         Public Library                   library         Leipsic     3.0
# 30         Public Library                   library   Mount Victory     3.0
# 31         Public Library                   library          Ottawa     3.0
# 32         Public Library                   library       Ottoville     3.0
# 33         Public Library                   library         Pandora     3.0
# 34         Public Library                   library     Saint Marys     3.0
# 35         Public Library                   library    Cridersville     3.0
# 36         Public Library                   library         Dunkirk     3.0
# 37         Public Library                   library        Glandorf     3.0
# 38         Public Library                   library          Kenton     3.0
# 39         Public Library                   library          La Rue     3.0
# 40         Public Library                   library         Leipsic     3.0
# 41         Public Library                   library            Lima     3.0
# 42         Public Library                   library          Marion     3.0
# 43         Public Library                   library         Minster     3.0
# 44         Public Library                   library          Nevada     3.0
# 45         Public Library                   library      New Bremen     3.0
# 46         Public Library                   library   New Knoxville     3.0
# 47         Public Library                   library        Prospect     3.0
# 48         Public Library                   library    Spencerville     3.0
# 49         Public Library                   library        Sycamore     3.0
# 50         Public Library                   library  Upper Sandusky     3.0
# 51         Public Library                   library      Wapakoneta     3.0
# 52         Public Library                   library     Waynesfield     3.0
# 53  Delphos Senior Center          senior community         Delphos     7.0
# 54            HardinCrest          senior community          Kenton     2.0
# 55           HardinCrest           senior community          Kenton     2.0
# 56           Kenton Seton          senior community          Kenton     0.0
# 57           Seton Kenton          senior community          Kenton     3.0
# 58     Mercy Thrift Store              thrift store            Lima     0.0
# 59                Restore              thrift store            Lima     3.0
#
#     medAtt  maxAtt
# 0      3.0     5.0
# 1      3.0     3.0
# 2      2.0     2.0
# 3      3.0     7.0
# 4      3.0     4.0
# 5      3.0     7.0
# 6      6.0     6.0
# 7      3.0    10.0
# 8      6.0    10.0
# 9      4.0     6.0
# 10     0.0     6.0
# 11     2.0     2.0
# 12     3.0     5.0
# 13     3.0     3.0
# 14     2.0     4.0
# 15     7.0    10.0
# 16     3.0     3.0
# 17     6.0    10.0
# 18     6.0    10.0
# 19     6.0    10.0
# 20     6.0    10.0
# 21     6.0    10.0
# 22     6.0    10.0
# 23     6.0    10.0
# 24     6.0    10.0
# 25     6.0    10.0
# 26     6.0    10.0
# 27     6.0    10.0
# 28     6.0    10.0
# 29     6.0    10.0
# 30     6.0    10.0
# 31     6.0    10.0
# 32     6.0    10.0
# 33     6.0    10.0
# 34     6.0    10.0
# 35     6.0    10.0
# 36     6.0    10.0
# 37     6.0    10.0
# 38     6.0    10.0
# 39     6.0    10.0
# 40     6.0    10.0
# 41     6.0    10.0
# 42     6.0    10.0
# 43     6.0    10.0
# 44     6.0    10.0
# 45     6.0    10.0
# 46     6.0    10.0
# 47     6.0    10.0
# 48     6.0    10.0
# 49     6.0    10.0
# 50     6.0    10.0
# 51     6.0    10.0
# 52     6.0    10.0
# 53     7.0     7.0
# 54     3.0     5.0
# 55     2.0     3.0
# 56     4.0     5.0
# 57     6.0    10.0
# 58     1.0     4.0
# 59     3.0     9.0

# %% [markdown]
# ## Export data

# %%
propSites.to_csv("data/proposedSitesProcessed.csv")
